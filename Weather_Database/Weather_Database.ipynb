# %%
# importing Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

from citipy import citipy
from config import weather_api_key

# %%
#Creating 2,000 random latitude and longitude combinations

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 748

# %%
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval")


record_count = 1
set_count = 1

for i, city  in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found.")
        pass


print("Data Retrieval Complete")
# Out:
# Beginning Data Retrieval
# Processing Record 1 of Set 1 | haines junction
# Processing Record 2 of Set 1 | lobito
# Processing Record 3 of Set 1 | samusu
# City not found.
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | muros
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | saskylakh
# Processing Record 8 of Set 1 | segezha
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | usatove
# Processing Record 11 of Set 1 | aitape
# Processing Record 12 of Set 1 | gornyy
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | muzhi
# Processing Record 16 of Set 1 | dikson
# Processing Record 17 of Set 1 | taolanaro
# City not found.
# Processing Record 18 of Set 1 | komsomolskiy
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | tasiilaq
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | druskininkai
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | mahanoro
# Processing Record 25 of Set 1 | zubtsov
# Processing Record 26 of Set 1 | ygatimi
# Processing Record 27 of Set 1 | vardo
# Processing Record 28 of Set 1 | svetlyy
# Processing Record 29 of Set 1 | cabo san lucas
# Processing Record 30 of Set 1 | clyde river
# Processing Record 31 of Set 1 | cidreira
# Processing Record 32 of Set 1 | saint-joseph
# Processing Record 33 of Set 1 | castro
# Processing Record 34 of Set 1 | tuktoyaktuk
# Processing Record 35 of Set 1 | jumla
# Processing Record 36 of Set 1 | port alfred
# Processing Record 37 of Set 1 | illoqqortoormiut
# City not found.
# Processing Record 38 of Set 1 | deniliquin
# Processing Record 39 of Set 1 | samfya
# Processing Record 40 of Set 1 | nizhneyansk
# City not found.
# Processing Record 41 of Set 1 | hwange
# Processing Record 42 of Set 1 | turukhansk
# Processing Record 43 of Set 1 | faanui
# Processing Record 44 of Set 1 | rikitea
# Processing Record 45 of Set 1 | ondjiva
# Processing Record 46 of Set 1 | busselton
# Processing Record 47 of Set 1 | porosozero
# Processing Record 48 of Set 1 | yulara
# Processing Record 49 of Set 1 | barentsburg
# City not found.
# Processing Record 50 of Set 1 | misawa
# Processing Record 1 of Set 2 | mahebourg
# Processing Record 2 of Set 2 | pevek
# Processing Record 3 of Set 2 | klaksvik
# Processing Record 4 of Set 2 | sorland
# Processing Record 5 of Set 2 | jamestown
# Processing Record 6 of Set 2 | nikolskoye
# Processing Record 7 of Set 2 | sandwick
# Processing Record 8 of Set 2 | saint-philippe
# Processing Record 9 of Set 2 | krutikha
# Processing Record 10 of Set 2 | lata
# Processing Record 11 of Set 2 | longyearbyen
# Processing Record 12 of Set 2 | saint-augustin
# Processing Record 13 of Set 2 | mahemdavad
# Processing Record 14 of Set 2 | talcahuano
# Processing Record 15 of Set 2 | mataura
# Processing Record 16 of Set 2 | cape town
# Processing Record 17 of Set 2 | kodiak
# Processing Record 18 of Set 2 | esperance
# Processing Record 19 of Set 2 | chino valley
# Processing Record 20 of Set 2 | khatanga
# Processing Record 21 of Set 2 | bethel
# Processing Record 22 of Set 2 | lebu
# Processing Record 23 of Set 2 | satitoa
# City not found.
# Processing Record 24 of Set 2 | port-gentil
# Processing Record 25 of Set 2 | nador
# Processing Record 26 of Set 2 | sobreira
# Processing Record 27 of Set 2 | laguna
# Processing Record 28 of Set 2 | luderitz
# Processing Record 29 of Set 2 | chake chake
# Processing Record 30 of Set 2 | vila franca do campo
# Processing Record 31 of Set 2 | carballo
# Processing Record 32 of Set 2 | talnakh
# Processing Record 33 of Set 2 | nepalganj
# City not found.
# Processing Record 34 of Set 2 | kapaa
# Processing Record 35 of Set 2 | jiwani
# Processing Record 36 of Set 2 | langham
# Processing Record 37 of Set 2 | alofi
# Processing Record 38 of Set 2 | east london
# Processing Record 39 of Set 2 | qaanaaq
# Processing Record 40 of Set 2 | biak
# Processing Record 41 of Set 2 | saint george
# Processing Record 42 of Set 2 | kavaratti
# Processing Record 43 of Set 2 | vaini
# Processing Record 44 of Set 2 | ercis
# Processing Record 45 of Set 2 | mayumba
# Processing Record 46 of Set 2 | port blair
# Processing Record 47 of Set 2 | hilo
# Processing Record 48 of Set 2 | kalangala
# Processing Record 49 of Set 2 | haimen
# Processing Record 50 of Set 2 | christchurch
# Processing Record 1 of Set 3 | zhicheng
# Processing Record 2 of Set 3 | kirakira
# Processing Record 3 of Set 3 | hobart
# Processing Record 4 of Set 3 | ancud
# Processing Record 5 of Set 3 | steamboat springs
# Processing Record 6 of Set 3 | guanica
# Processing Record 7 of Set 3 | upernavik
# Processing Record 8 of Set 3 | waddan
# Processing Record 9 of Set 3 | emerald
# Processing Record 10 of Set 3 | sompeta
# Processing Record 11 of Set 3 | nortelandia
# Processing Record 12 of Set 3 | spearfish
# Processing Record 13 of Set 3 | atuona
# Processing Record 14 of Set 3 | buqayq
# City not found.
# Processing Record 15 of Set 3 | kruisfontein
# Processing Record 16 of Set 3 | kagoro
# Processing Record 17 of Set 3 | punta arenas
# Processing Record 18 of Set 3 | ilulissat
# Processing Record 19 of Set 3 | alyangula
# Processing Record 20 of Set 3 | pangkalanbuun
# Processing Record 21 of Set 3 | port elizabeth
# Processing Record 22 of Set 3 | bol
# Processing Record 23 of Set 3 | namibe
# Processing Record 24 of Set 3 | sambava
# Processing Record 25 of Set 3 | aswan
# Processing Record 26 of Set 3 | mezen
# Processing Record 27 of Set 3 | hithadhoo
# Processing Record 28 of Set 3 | mehamn
# Processing Record 29 of Set 3 | kaitangata
# Processing Record 30 of Set 3 | cap-aux-meules
# Processing Record 31 of Set 3 | sterling
# Processing Record 32 of Set 3 | salamanca
# Processing Record 33 of Set 3 | thompson
# Processing Record 34 of Set 3 | tocopilla
# Processing Record 35 of Set 3 | mendahara
# City not found.
# Processing Record 36 of Set 3 | marzuq
# Processing Record 37 of Set 3 | porto novo
# Processing Record 38 of Set 3 | tan an
# Processing Record 39 of Set 3 | belushya guba
# City not found.
# Processing Record 40 of Set 3 | meadow lake
# Processing Record 41 of Set 3 | zile
# Processing Record 42 of Set 3 | whithorn
# Processing Record 43 of Set 3 | nome
# Processing Record 44 of Set 3 | terrace bay
# Processing Record 45 of Set 3 | bodden town
# Processing Record 46 of Set 3 | tubruq
# City not found.
# Processing Record 47 of Set 3 | samarai
# Processing Record 48 of Set 3 | kudahuvadhoo
# Processing Record 49 of Set 3 | cherskiy
# Processing Record 50 of Set 3 | timra
# Processing Record 1 of Set 4 | barrow
# Processing Record 2 of Set 4 | totness
# Processing Record 3 of Set 4 | cayenne
# Processing Record 4 of Set 4 | san cristobal
# Processing Record 5 of Set 4 | tessalit
# Processing Record 6 of Set 4 | baghdad
# Processing Record 7 of Set 4 | torbay
# Processing Record 8 of Set 4 | evensk
# Processing Record 9 of Set 4 | dalvik
# Processing Record 10 of Set 4 | sola
# Processing Record 11 of Set 4 | ust-ishim
# Processing Record 12 of Set 4 | shypyntsi
# Processing Record 13 of Set 4 | dwarka
# Processing Record 14 of Set 4 | porto santo
# Processing Record 15 of Set 4 | macas
# Processing Record 16 of Set 4 | mar del plata
# Processing Record 17 of Set 4 | ribeira grande
# Processing Record 18 of Set 4 | sinazongwe
# Processing Record 19 of Set 4 | aksu
# Processing Record 20 of Set 4 | betera
# Processing Record 21 of Set 4 | clovis
# Processing Record 22 of Set 4 | matagami
# Processing Record 23 of Set 4 | victoria
# Processing Record 24 of Set 4 | hay river
# Processing Record 25 of Set 4 | aquiraz
# Processing Record 26 of Set 4 | tigil
# Processing Record 27 of Set 4 | mys shmidta
# City not found.
# Processing Record 28 of Set 4 | willmar
# Processing Record 29 of Set 4 | ostrovnoy
# Processing Record 30 of Set 4 | samarinda
# Processing Record 31 of Set 4 | saurimo
# Processing Record 32 of Set 4 | nyimba
# Processing Record 33 of Set 4 | amarante do maranhao
# Processing Record 34 of Set 4 | clarksburg
# Processing Record 35 of Set 4 | amapa
# Processing Record 36 of Set 4 | kodinsk
# Processing Record 37 of Set 4 | henties bay
# Processing Record 38 of Set 4 | katobu
# Processing Record 39 of Set 4 | bria
# Processing Record 40 of Set 4 | asau
# Processing Record 41 of Set 4 | tabou
# Processing Record 42 of Set 4 | isangel
# Processing Record 43 of Set 4 | georgetown
# Processing Record 44 of Set 4 | port hawkesbury
# Processing Record 45 of Set 4 | talara
# Processing Record 46 of Set 4 | codrington
# Processing Record 47 of Set 4 | constitucion
# Processing Record 48 of Set 4 | lompoc
# Processing Record 49 of Set 4 | praia da vitoria
# Processing Record 50 of Set 4 | volodarka
# Processing Record 1 of Set 5 | lagoa
# Processing Record 2 of Set 5 | conceicao do araguaia
# Processing Record 3 of Set 5 | santa cruz de la palma
# Processing Record 4 of Set 5 | portland
# Processing Record 5 of Set 5 | hofn
# Processing Record 6 of Set 5 | hare bay
# Processing Record 7 of Set 5 | san patricio
# Processing Record 8 of Set 5 | new norfolk
# Processing Record 9 of Set 5 | chokurdakh
# Processing Record 10 of Set 5 | fairbanks
# Processing Record 11 of Set 5 | zwedru
# Processing Record 12 of Set 5 | rundu
# Processing Record 13 of Set 5 | sidhi
# Processing Record 14 of Set 5 | arraial do cabo
# Processing Record 15 of Set 5 | iqaluit
# Processing Record 16 of Set 5 | hambantota
# Processing Record 17 of Set 5 | saint-francois
# Processing Record 18 of Set 5 | carnarvon
# Processing Record 19 of Set 5 | amderma
# City not found.
# Processing Record 20 of Set 5 | vaitupu
# City not found.
# Processing Record 21 of Set 5 | galiwinku
# City not found.
# Processing Record 22 of Set 5 | tartus
# Processing Record 23 of Set 5 | kavieng
# Processing Record 24 of Set 5 | tuggurt
# City not found.
# Processing Record 25 of Set 5 | grindavik
# Processing Record 26 of Set 5 | geraldton
# Processing Record 27 of Set 5 | auki
# Processing Record 28 of Set 5 | gazanjyk
# Processing Record 29 of Set 5 | baruun-urt
# Processing Record 30 of Set 5 | pangnirtung
# Processing Record 31 of Set 5 | praya
# Processing Record 32 of Set 5 | kenora
# Processing Record 33 of Set 5 | ligayan
# Processing Record 34 of Set 5 | golkoy
# Processing Record 35 of Set 5 | labrea
# Processing Record 36 of Set 5 | raga
# Processing Record 37 of Set 5 | ukiah
# Processing Record 38 of Set 5 | marsh harbour
# Processing Record 39 of Set 5 | the valley
# Processing Record 40 of Set 5 | trincomalee
# Processing Record 41 of Set 5 | latung
# Processing Record 42 of Set 5 | san mateo ixtatan
# Processing Record 43 of Set 5 | turinskaya sloboda
# Processing Record 44 of Set 5 | lusambo
# Processing Record 45 of Set 5 | sinop
# Processing Record 46 of Set 5 | norman wells
# Processing Record 47 of Set 5 | bengkulu
# Processing Record 48 of Set 5 | husavik
# Processing Record 49 of Set 5 | mengcheng
# Processing Record 50 of Set 5 | sibu
# Processing Record 1 of Set 6 | atbasar
# Processing Record 2 of Set 6 | magaramkent
# Processing Record 3 of Set 6 | eirunepe
# Processing Record 4 of Set 6 | kenai
# Processing Record 5 of Set 6 | pacific grove
# Processing Record 6 of Set 6 | butaritari
# Processing Record 7 of Set 6 | urumqi
# Processing Record 8 of Set 6 | narsaq
# Processing Record 9 of Set 6 | najran
# Processing Record 10 of Set 6 | binzhou
# Processing Record 11 of Set 6 | bad liebenwerda
# Processing Record 12 of Set 6 | saleaula
# City not found.
# Processing Record 13 of Set 6 | galveston
# Processing Record 14 of Set 6 | shirgaon
# Processing Record 15 of Set 6 | ambilobe
# Processing Record 16 of Set 6 | touros
# Processing Record 17 of Set 6 | college
# Processing Record 18 of Set 6 | prado
# Processing Record 19 of Set 6 | waipawa
# Processing Record 20 of Set 6 | tarecuato
# Processing Record 21 of Set 6 | bargal
# City not found.
# Processing Record 22 of Set 6 | rawson
# Processing Record 23 of Set 6 | bushehr
# Processing Record 24 of Set 6 | lashio
# Processing Record 25 of Set 6 | chachapoyas
# Processing Record 26 of Set 6 | miguel alves
# Processing Record 27 of Set 6 | clinton
# Processing Record 28 of Set 6 | coihaique
# Processing Record 29 of Set 6 | khash
# Processing Record 30 of Set 6 | sayat
# Processing Record 31 of Set 6 | assiniboia
# Processing Record 32 of Set 6 | tumannyy
# City not found.
# Processing Record 33 of Set 6 | sao filipe
# Processing Record 34 of Set 6 | gurupi
# Processing Record 35 of Set 6 | sentyabrskiy
# City not found.
# Processing Record 36 of Set 6 | goba
# Processing Record 37 of Set 6 | charters towers
# Processing Record 38 of Set 6 | rungata
# City not found.
# Processing Record 39 of Set 6 | namatanai
# Processing Record 40 of Set 6 | roros
# Processing Record 41 of Set 6 | qaqortoq
# Processing Record 42 of Set 6 | maghama
# City not found.
# Processing Record 43 of Set 6 | lubango
# Processing Record 44 of Set 6 | florianopolis
# Processing Record 45 of Set 6 | aberdeen
# Processing Record 46 of Set 6 | marawi
# Processing Record 47 of Set 6 | tiksi
# Processing Record 48 of Set 6 | changping
# Processing Record 49 of Set 6 | asfi
# Processing Record 50 of Set 6 | guerrero negro
# Processing Record 1 of Set 7 | nova olimpia
# Processing Record 2 of Set 7 | ngukurr
# City not found.
# Processing Record 3 of Set 7 | oxford
# Processing Record 4 of Set 7 | kaoma
# Processing Record 5 of Set 7 | daru
# Processing Record 6 of Set 7 | faya
# Processing Record 7 of Set 7 | maues
# Processing Record 8 of Set 7 | nizwa
# Processing Record 9 of Set 7 | rio gallegos
# Processing Record 10 of Set 7 | airai
# Processing Record 11 of Set 7 | marcona
# City not found.
# Processing Record 12 of Set 7 | baryatino
# Processing Record 13 of Set 7 | lamu
# Processing Record 14 of Set 7 | abu samrah
# Processing Record 15 of Set 7 | phalaborwa
# Processing Record 16 of Set 7 | tsihombe
# City not found.
# Processing Record 17 of Set 7 | dingle
# Processing Record 18 of Set 7 | sorvag
# City not found.
# Processing Record 19 of Set 7 | letnyaya stavka
# Processing Record 20 of Set 7 | los llanos de aridane
# Processing Record 21 of Set 7 | liverpool
# Processing Record 22 of Set 7 | uvira
# Processing Record 23 of Set 7 | paamiut
# Processing Record 24 of Set 7 | genhe
# Processing Record 25 of Set 7 | patti
# Processing Record 26 of Set 7 | awbari
# Processing Record 27 of Set 7 | doctor arroyo
# Processing Record 28 of Set 7 | bubaque
# Processing Record 29 of Set 7 | leningradskiy
# Processing Record 30 of Set 7 | parauna
# Processing Record 31 of Set 7 | general bravo
# Processing Record 32 of Set 7 | guangshui
# Processing Record 33 of Set 7 | beringovskiy
# Processing Record 34 of Set 7 | nanortalik
# Processing Record 35 of Set 7 | wuda
# Processing Record 36 of Set 7 | muisne
# Processing Record 37 of Set 7 | lolua
# City not found.
# Processing Record 38 of Set 7 | kinanah
# City not found.
# Processing Record 39 of Set 7 | bushenyi
# Processing Record 40 of Set 7 | sitka
# Processing Record 41 of Set 7 | quelimane
# Processing Record 42 of Set 7 | iskateley
# Processing Record 43 of Set 7 | carman
# Processing Record 44 of Set 7 | finschhafen
# Processing Record 45 of Set 7 | chuy
# Processing Record 46 of Set 7 | saint-georges
# Processing Record 47 of Set 7 | luza
# Processing Record 48 of Set 7 | san policarpo
# Processing Record 49 of Set 7 | sao luiz gonzaga
# Processing Record 50 of Set 7 | north myrtle beach
# Processing Record 1 of Set 8 | koygorodok
# Processing Record 2 of Set 8 | lgov
# Processing Record 3 of Set 8 | ballina
# Processing Record 4 of Set 8 | port lincoln
# Processing Record 5 of Set 8 | otane
# Processing Record 6 of Set 8 | visnes
# Processing Record 7 of Set 8 | saint anthony
# Processing Record 8 of Set 8 | barcelos
# Processing Record 9 of Set 8 | souillac
# Processing Record 10 of Set 8 | pasni
# Processing Record 11 of Set 8 | itoman
# Processing Record 12 of Set 8 | paka
# Processing Record 13 of Set 8 | sulangan
# Processing Record 14 of Set 8 | kungurtug
# Processing Record 15 of Set 8 | along
# Processing Record 16 of Set 8 | vilhena
# Processing Record 17 of Set 8 | mount isa
# Processing Record 18 of Set 8 | hopkinsville
# Processing Record 19 of Set 8 | dieppe
# Processing Record 20 of Set 8 | yar-sale
# Processing Record 21 of Set 8 | baculin
# Processing Record 22 of Set 8 | kieta
# Processing Record 23 of Set 8 | milingimbi
# City not found.
# Processing Record 24 of Set 8 | schroeder
# Processing Record 25 of Set 8 | comodoro rivadavia
# Processing Record 26 of Set 8 | noumea
# Processing Record 27 of Set 8 | ugep
# Processing Record 28 of Set 8 | bambous virieux
# Processing Record 29 of Set 8 | naryan-mar
# Processing Record 30 of Set 8 | modasa
# Processing Record 31 of Set 8 | moussoro
# Processing Record 32 of Set 8 | severo-kurilsk
# Processing Record 33 of Set 8 | homer
# Processing Record 34 of Set 8 | attawapiskat
# City not found.
# Processing Record 35 of Set 8 | buala
# Processing Record 36 of Set 8 | abnub
# Processing Record 37 of Set 8 | obo
# Processing Record 38 of Set 8 | bermejo
# Processing Record 39 of Set 8 | damascus
# Processing Record 40 of Set 8 | salinas
# Processing Record 41 of Set 8 | wamba
# Processing Record 42 of Set 8 | sasvad
# Processing Record 43 of Set 8 | hokitika
# Processing Record 44 of Set 8 | tura
# Processing Record 45 of Set 8 | katsuura
# Processing Record 46 of Set 8 | vestmannaeyjar
# Processing Record 47 of Set 8 | mount gambier
# Processing Record 48 of Set 8 | taguatinga
# Processing Record 49 of Set 8 | merauke
# Processing Record 50 of Set 8 | fort nelson
# Processing Record 1 of Set 9 | axim
# Processing Record 2 of Set 9 | jalu
# Processing Record 3 of Set 9 | necochea
# Processing Record 4 of Set 9 | caravelas
# Processing Record 5 of Set 9 | hualmay
# Processing Record 6 of Set 9 | pipar
# Processing Record 7 of Set 9 | urdzhar
# City not found.
# Processing Record 8 of Set 9 | atar
# Processing Record 9 of Set 9 | chapais
# Processing Record 10 of Set 9 | ostersund
# Processing Record 11 of Set 9 | pisco
# Processing Record 12 of Set 9 | ramnagar
# Processing Record 13 of Set 9 | karaul
# City not found.
# Processing Record 14 of Set 9 | maltahohe
# Processing Record 15 of Set 9 | viloco
# Processing Record 16 of Set 9 | dubbo
# Processing Record 17 of Set 9 | roald
# Processing Record 18 of Set 9 | fortuna
# Processing Record 19 of Set 9 | kahului
# Processing Record 20 of Set 9 | garmsar
# Processing Record 21 of Set 9 | barberton
# Processing Record 22 of Set 9 | prince george
# Processing Record 23 of Set 9 | georgiyevka
# Processing Record 24 of Set 9 | ponta do sol
# Processing Record 25 of Set 9 | nicoya
# Processing Record 26 of Set 9 | ahipara
# Processing Record 27 of Set 9 | flinders
# Processing Record 28 of Set 9 | korla
# Processing Record 29 of Set 9 | burica
# City not found.
# Processing Record 30 of Set 9 | pailon
# Processing Record 31 of Set 9 | tongchuan
# Processing Record 32 of Set 9 | dali
# Processing Record 33 of Set 9 | canatlan
# Processing Record 34 of Set 9 | vallenar
# Processing Record 35 of Set 9 | bougouni
# Processing Record 36 of Set 9 | lorengau
# Processing Record 37 of Set 9 | leeton
# Processing Record 38 of Set 9 | eyl
# Processing Record 39 of Set 9 | salalah
# Processing Record 40 of Set 9 | kindu
# Processing Record 41 of Set 9 | fort myers beach
# Processing Record 42 of Set 9 | amurzet
# Processing Record 43 of Set 9 | mahenge
# Processing Record 44 of Set 9 | tabiauea
# City not found.
# Processing Record 45 of Set 9 | fomboni
# Processing Record 46 of Set 9 | bathsheba
# Processing Record 47 of Set 9 | lavrentiya
# Processing Record 48 of Set 9 | northam
# Processing Record 49 of Set 9 | turayf
# Processing Record 50 of Set 9 | darhan
# Processing Record 1 of Set 10 | santa catalina
# Processing Record 2 of Set 10 | louisbourg
# City not found.
# Processing Record 3 of Set 10 | aloleng
# Processing Record 4 of Set 10 | padang
# Processing Record 5 of Set 10 | bajil
# Processing Record 6 of Set 10 | prattville
# Processing Record 7 of Set 10 | shihezi
# Processing Record 8 of Set 10 | la romana
# Processing Record 9 of Set 10 | san quintin
# Processing Record 10 of Set 10 | san jeronimo
# Processing Record 11 of Set 10 | makurdi
# Processing Record 12 of Set 10 | batticaloa
# Processing Record 13 of Set 10 | tumut
# Processing Record 14 of Set 10 | palmer
# Processing Record 15 of Set 10 | kyzyl-suu
# Processing Record 16 of Set 10 | hobyo
# Processing Record 17 of Set 10 | hermosillo
# Processing Record 18 of Set 10 | frontera
# Processing Record 19 of Set 10 | yerbogachen
# Processing Record 20 of Set 10 | gallup
# Processing Record 21 of Set 10 | cooma
# Processing Record 22 of Set 10 | khasan
# Processing Record 23 of Set 10 | vila velha
# Processing Record 24 of Set 10 | burgeo
# Processing Record 25 of Set 10 | mansa
# Processing Record 26 of Set 10 | murupara
# Processing Record 27 of Set 10 | japura
# Processing Record 28 of Set 10 | manono
# Processing Record 29 of Set 10 | natal
# Processing Record 30 of Set 10 | tela
# Processing Record 31 of Set 10 | provideniya
# Processing Record 32 of Set 10 | porto nacional
# Processing Record 33 of Set 10 | tautira
# Processing Record 34 of Set 10 | mbandaka
# Processing Record 35 of Set 10 | arman
# Processing Record 36 of Set 10 | metro
# Processing Record 37 of Set 10 | champerico
# Processing Record 38 of Set 10 | borujan
# City not found.
# Processing Record 39 of Set 10 | nongan
# Processing Record 40 of Set 10 | wanning
# Processing Record 41 of Set 10 | erdenet
# Processing Record 42 of Set 10 | whitehorse
# Processing Record 43 of Set 10 | leshukonskoye
# Processing Record 44 of Set 10 | rocha
# Processing Record 45 of Set 10 | ust-koksa
# Processing Record 46 of Set 10 | rock springs
# Processing Record 47 of Set 10 | luwuk
# Processing Record 48 of Set 10 | andenes
# Processing Record 49 of Set 10 | beloha
# Processing Record 50 of Set 10 | aksarka
# Processing Record 1 of Set 11 | florida
# Processing Record 2 of Set 11 | koungheul
# Processing Record 3 of Set 11 | zaysan
# Processing Record 4 of Set 11 | amuntai
# Processing Record 5 of Set 11 | teguldet
# Processing Record 6 of Set 11 | golden
# Processing Record 7 of Set 11 | port-cartier
# Processing Record 8 of Set 11 | turgutlu
# Processing Record 9 of Set 11 | tongliao
# Processing Record 10 of Set 11 | loutra ipatis
# City not found.
# Processing Record 11 of Set 11 | khani
# Processing Record 12 of Set 11 | bousso
# Processing Record 13 of Set 11 | hindaun
# Processing Record 14 of Set 11 | tual
# Processing Record 15 of Set 11 | sahuaripa
# Processing Record 16 of Set 11 | nemuro
# Processing Record 17 of Set 11 | aracati
# Processing Record 18 of Set 11 | karratha
# Processing Record 19 of Set 11 | topolobampo
# Processing Record 20 of Set 11 | naldurg
# Processing Record 21 of Set 11 | kulhudhuffushi
# Processing Record 22 of Set 11 | raudeberg
# Processing Record 23 of Set 11 | tukrah
# Processing Record 24 of Set 11 | ridgecrest
# Processing Record 25 of Set 11 | meulaboh
# Processing Record 26 of Set 11 | haibowan
# City not found.
# Processing Record 27 of Set 11 | menongue
# Processing Record 28 of Set 11 | thano bula khan
# City not found.
# Processing Record 29 of Set 11 | ankang
# Processing Record 30 of Set 11 | san francisco
# Processing Record 31 of Set 11 | vao
# Processing Record 32 of Set 11 | kaihua
# Processing Record 33 of Set 11 | bolshoye sorokino
# City not found.
# Processing Record 34 of Set 11 | kasongo-lunda
# Processing Record 35 of Set 11 | tambul
# City not found.
# Processing Record 36 of Set 11 | stromness
# Processing Record 37 of Set 11 | polson
# Processing Record 38 of Set 11 | paldiski
# Processing Record 39 of Set 11 | cangucu
# Processing Record 40 of Set 11 | verkhnevilyuysk
# Processing Record 41 of Set 11 | shimoda
# Processing Record 42 of Set 11 | skibbereen
# Processing Record 43 of Set 11 | betsiamites
# Processing Record 44 of Set 11 | nanyuki
# Processing Record 45 of Set 11 | benguela
# Processing Record 46 of Set 11 | vanimo
# Processing Record 47 of Set 11 | kristiansand
# Processing Record 48 of Set 11 | westport
# Processing Record 49 of Set 11 | hovd
# Processing Record 50 of Set 11 | sabha
# Processing Record 1 of Set 12 | shetpe
# Processing Record 2 of Set 12 | fort collins
# Processing Record 3 of Set 12 | katangli
# Processing Record 4 of Set 12 | sur
# Processing Record 5 of Set 12 | garissa
# Processing Record 6 of Set 12 | beian
# Processing Record 7 of Set 12 | canico
# Processing Record 8 of Set 12 | bereda
# Processing Record 9 of Set 12 | tomatlan
# Processing Record 10 of Set 12 | corrales
# Processing Record 11 of Set 12 | brownsville
# Processing Record 12 of Set 12 | ocala
# Processing Record 13 of Set 12 | peniche
# Processing Record 14 of Set 12 | grand gaube
# Processing Record 15 of Set 12 | sobolevo
# Processing Record 16 of Set 12 | simao
# Processing Record 17 of Set 12 | pochutla
# Processing Record 18 of Set 12 | kananga
# Processing Record 19 of Set 12 | stovring
# Processing Record 20 of Set 12 | kununurra
# Processing Record 21 of Set 12 | pompeu
# Processing Record 22 of Set 12 | sao joao da barra
# Processing Record 23 of Set 12 | creel
# Processing Record 24 of Set 12 | mitu
# Processing Record 25 of Set 12 | presque isle
# Processing Record 26 of Set 12 | kundiawa
# Processing Record 27 of Set 12 | isny
# Processing Record 28 of Set 12 | espanola
# Processing Record 29 of Set 12 | palana
# Processing Record 30 of Set 12 | tambovka
# Processing Record 31 of Set 12 | kargasok
# Processing Record 32 of Set 12 | zemio
# Processing Record 33 of Set 12 | inderborskiy
# City not found.
# Processing Record 34 of Set 12 | oktyabrskiy
# Processing Record 35 of Set 12 | ust-bolsheretsk
# City not found.
# Processing Record 36 of Set 12 | shenkursk
# Processing Record 37 of Set 12 | george town
# Processing Record 38 of Set 12 | shumskiy
# Processing Record 39 of Set 12 | harper
# Processing Record 40 of Set 12 | saint-pierre
# Processing Record 41 of Set 12 | palabuhanratu
# City not found.
# Processing Record 42 of Set 12 | sistranda
# Processing Record 43 of Set 12 | hami
# Processing Record 44 of Set 12 | honiara
# Processing Record 45 of Set 12 | san luis
# Processing Record 46 of Set 12 | coahuayana
# Processing Record 47 of Set 12 | taybad
# Processing Record 48 of Set 12 | port hedland
# Processing Record 49 of Set 12 | crixas
# Processing Record 50 of Set 12 | hamilton
# Processing Record 1 of Set 13 | mumford
# Processing Record 2 of Set 13 | san andres
# Processing Record 3 of Set 13 | iberia
# Processing Record 4 of Set 13 | tulsipur
# Processing Record 5 of Set 13 | saint-paul
# Processing Record 6 of Set 13 | nishihara
# Processing Record 7 of Set 13 | pasewalk
# Processing Record 8 of Set 13 | gushikawa
# Processing Record 9 of Set 13 | basco
# Processing Record 10 of Set 13 | grand centre
# City not found.
# Processing Record 11 of Set 13 | nhulunbuy
# Processing Record 12 of Set 13 | ahuimanu
# Processing Record 13 of Set 13 | katha
# City not found.
# Processing Record 14 of Set 13 | goroka
# Processing Record 15 of Set 13 | greenville
# Processing Record 16 of Set 13 | alta floresta
# Processing Record 17 of Set 13 | abalak
# Processing Record 18 of Set 13 | pueblo
# Processing Record 19 of Set 13 | qui nhon
# Processing Record 20 of Set 13 | port keats
# Processing Record 21 of Set 13 | zadar
# Processing Record 22 of Set 13 | worland
# Processing Record 23 of Set 13 | egvekinot
# Processing Record 24 of Set 13 | tateyama
# Processing Record 25 of Set 13 | mahdasht
# Processing Record 26 of Set 13 | longlac
# City not found.
# Processing Record 27 of Set 13 | ivybridge
# Processing Record 28 of Set 13 | quatre cocos
# Processing Record 29 of Set 13 | sosnovo-ozerskoye
# Processing Record 30 of Set 13 | azul
# Processing Record 31 of Set 13 | riberalta
# Processing Record 32 of Set 13 | ternate
# Processing Record 33 of Set 13 | kurumkan
# Processing Record 34 of Set 13 | olinda
# Processing Record 35 of Set 13 | harnosand
# Processing Record 36 of Set 13 | hervey bay
# Processing Record 37 of Set 13 | armidale
# Processing Record 38 of Set 13 | kashary
# Processing Record 39 of Set 13 | talipparamba
# Processing Record 40 of Set 13 | kaifeng
# Processing Record 41 of Set 13 | aanekoski
# Processing Record 42 of Set 13 | athabasca
# Processing Record 43 of Set 13 | camapua
# Processing Record 44 of Set 13 | takoradi
# Processing Record 45 of Set 13 | lasa
# Processing Record 46 of Set 13 | grand baie
# Processing Record 47 of Set 13 | sessa aurunca
# Processing Record 48 of Set 13 | burnie
# Processing Record 49 of Set 13 | chilpancingo
# Processing Record 50 of Set 13 | naantali
# Processing Record 1 of Set 14 | miri
# Processing Record 2 of Set 14 | marquette
# Processing Record 3 of Set 14 | san juan
# Processing Record 4 of Set 14 | jieshi
# Processing Record 5 of Set 14 | banepa
# Processing Record 6 of Set 14 | portugalete
# Processing Record 7 of Set 14 | angoche
# Processing Record 8 of Set 14 | kazachinskoye
# Processing Record 9 of Set 14 | manaure
# Processing Record 10 of Set 14 | andra
# Processing Record 11 of Set 14 | bhuban
# Processing Record 12 of Set 14 | tema
# Processing Record 13 of Set 14 | tezu
# Processing Record 14 of Set 14 | taltal
# Processing Record 15 of Set 14 | suntar
# Processing Record 16 of Set 14 | labuhan
# Processing Record 17 of Set 14 | sakaiminato
# Processing Record 18 of Set 14 | trondheim
# Processing Record 19 of Set 14 | boa vista
# Processing Record 20 of Set 14 | cabedelo
# Processing Record 21 of Set 14 | rawannawi
# City not found.
# Processing Record 22 of Set 14 | pundaguitan
# Processing Record 23 of Set 14 | bedford
# Processing Record 24 of Set 14 | cessnock
# Processing Record 25 of Set 14 | grand river south east
# City not found.
# Processing Record 26 of Set 14 | billings
# Processing Record 27 of Set 14 | vyazma
# Processing Record 28 of Set 14 | bossangoa
# Processing Record 29 of Set 14 | innisfail
# Processing Record 30 of Set 14 | balaipungut
# Processing Record 31 of Set 14 | mastic beach
# Processing Record 32 of Set 14 | hvide sande
# Processing Record 33 of Set 14 | strezhevoy
# Processing Record 34 of Set 14 | forset
# City not found.
# Processing Record 35 of Set 14 | tsogni
# Processing Record 36 of Set 14 | belaya gora
# Processing Record 37 of Set 14 | zdvinsk
# Processing Record 38 of Set 14 | concordia
# Processing Record 39 of Set 14 | bonthe
# Processing Record 40 of Set 14 | ariquemes
# Processing Record 41 of Set 14 | mpika
# Processing Record 42 of Set 14 | villa del rosario
# Processing Record 43 of Set 14 | lagos
# Processing Record 44 of Set 14 | llanes
# Processing Record 45 of Set 14 | quibdo
# Processing Record 46 of Set 14 | huarmey
# Processing Record 47 of Set 14 | diego de almagro
# Processing Record 48 of Set 14 | kapit
# Processing Record 49 of Set 14 | zelenogradsk
# Processing Record 50 of Set 14 | gidole
# Processing Record 1 of Set 15 | camacha
# Processing Record 2 of Set 15 | alice springs
# Processing Record 3 of Set 15 | puerto escondido
# Processing Record 4 of Set 15 | coromandel
# Processing Record 5 of Set 15 | polunochnoye
# Processing Record 6 of Set 15 | plouzane
# Processing Record 7 of Set 15 | araouane
# Processing Record 8 of Set 15 | pierre
# Processing Record 9 of Set 15 | paita
# Processing Record 10 of Set 15 | aykhal
# Processing Record 11 of Set 15 | balkhash
# Processing Record 12 of Set 15 | karasuk
# Processing Record 13 of Set 15 | pulaski
# Processing Record 14 of Set 15 | becerril
# Processing Record 15 of Set 15 | trelew
# Processing Record 16 of Set 15 | antigonish
# Processing Record 17 of Set 15 | eureka
# Processing Record 18 of Set 15 | dhidhdhoo
# Processing Record 19 of Set 15 | ongole
# Processing Record 20 of Set 15 | kuching
# Processing Record 21 of Set 15 | dalianwan
# Processing Record 22 of Set 15 | alamogordo
# Processing Record 23 of Set 15 | doctor pedro p. pena
# City not found.
# Processing Record 24 of Set 15 | kozhva
# Processing Record 25 of Set 15 | rio pomba
# Processing Record 26 of Set 15 | kiraoli
# Processing Record 27 of Set 15 | cap malheureux
# Processing Record 28 of Set 15 | litovko
# Processing Record 29 of Set 15 | pozo colorado
# Processing Record 30 of Set 15 | gari
# Processing Record 31 of Set 15 | kaiyuan
# Processing Record 32 of Set 15 | la gaulette
# City not found.
# Processing Record 33 of Set 15 | mamaku
# Processing Record 34 of Set 15 | totma
# Processing Record 35 of Set 15 | matay
# Processing Record 36 of Set 15 | brae
# Processing Record 37 of Set 15 | washougal
# Processing Record 38 of Set 15 | cruzeiro do sul
# Processing Record 39 of Set 15 | richards bay
# Processing Record 40 of Set 15 | mayo
# Processing Record 41 of Set 15 | grootfontein
# Processing Record 42 of Set 15 | udachnyy
# Processing Record 43 of Set 15 | astoria
# Processing Record 44 of Set 15 | dudinka
# Processing Record 45 of Set 15 | vangaindrano
# Processing Record 46 of Set 15 | tarko-sale
# Processing Record 47 of Set 15 | kaman
# Processing Record 48 of Set 15 | eravur
# Data Retrieval Complete

# %%
# City Data Frame
city_data_df = pd.DataFrame(city_data)

city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Haines Junction      CA  60.7522 -137.5108     19.35        73         100
# 1           Lobito      AO -12.3481   13.5456     77.07        81          82
# 2       Bredasdorp      ZA -34.5322   20.0403     67.32        77          92
# 3            Muros      ES  42.7762   -9.0603     55.83        73           9
# 4           Albany      US  42.6001  -73.9662     26.31        53         100
# 5        Saskylakh      RU  71.9167  114.0833    -16.60        86          26
# 6          Segezha      RU  63.7415   34.3222     28.90        95         100
# 7      Yellowknife      CA  62.4560 -114.3525    -10.59        67          20
# 8          Usatove      UA  46.5330   30.6596     26.82        93          93
# 9           Aitape      PG  -3.1374  142.3475     77.36        89         100
#
#    Wind Speed Current Description
# 0        0.00     overcast clouds
# 1        3.44       broken clouds
# 2       12.66     overcast clouds
# 3       18.28           clear sky
# 4        1.01     overcast clouds
# 5        3.22    scattered clouds
# 6       14.81          light snow
# 7        4.61          few clouds
# 8        0.00     overcast clouds
# 9        4.45     overcast clouds

# %%
# Writing City Data CSV
output_data_file = "WeatherPy_Database.csv"

city_data_df.to_csv(output_data_file, index_label='City_ID')
